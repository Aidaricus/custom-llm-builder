# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.llm_platform.data_foundry.sanitizer import DatasetSanitizer

sanitizer = DatasetSanitizer(similarity_threshold=0.85)

input_file = project_root / "data/processed/test_sft_dataset.jsonl" # Наш сырой датасет с этапа Evol
output_file = project_root / "data/sanitized/sanitized_sft_dataset.jsonl"

stats = sanitizer.sanitize_sft(input_file, output_file)

print("--- Статистика очистки SFT ---")
for key, value in stats.items():
    print(f"{key}: {value}")
# Out:
# --- Статистика очистки SFT ---
# total_processed: 81
# passed: 80
# rejected_refusal: 0
# rejected_length: 0
# rejected_duplicate: 0
# rejected_structure: 1

# %%
print("\n--- Статистика очистки DPO ---")
dpo_input = project_root / "data/processed/test_dpo_dataset.jsonl"
dpo_output = project_root / "data/sanitized/sanitized_dpo_dataset.jsonl"

dpo_stats = sanitizer.sanitize_dpo(dpo_input, dpo_output)

for key, value in dpo_stats.items():
    print(f"{key}: {value}")
# Out:
# --- Статистика очистки DPO ---
# total_processed: 49
# passed: 48
# rejected_structure: 0
# rejected_refusal: 0
# rejected_similarity: 1
# rejected_length: 0
