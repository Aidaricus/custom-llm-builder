# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

project_root = Path.cwd().parent
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from src.llm_platform.data_foundry.dataset_formatter import DatasetFormatter

# Инициализируем форматер
formatter = DatasetFormatter(seed=42)

print("--- Форматирование SFT датасета ---")
sft_input = project_root / "data/sanitized/sanitized_sft_dataset.jsonl"
sft_train = project_root / "data/formatted/sft_train.jsonl"
sft_test = project_root / "data/formatted/sft_test.jsonl"

formatter.format_sft(
    input_file=sft_input,
    train_file=sft_train,
    test_file=sft_test,
    train_ratio=0.9
)

print("\n--- Форматирование DPO датасета ---")
dpo_input = project_root / "data/processed/test_dpo_dataset.jsonl"
dpo_train = project_root / "data/formatted/dpo_train.jsonl"
dpo_test = project_root / "data/formatted/dpo_test.jsonl"

formatter.format_dpo(
    input_file=dpo_input,
    train_file=dpo_train,
    test_file=dpo_test,
    train_ratio=0.9
)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# --- Форматирование SFT датасета ---
#
# --- Форматирование DPO датасета ---
